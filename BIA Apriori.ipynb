# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('/Users/amardeepsingh/Desktop/Online Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# **Missing Values**

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Data : UCI Open ML Database : Groceries** >
# Cleaning and Preprocessing

# %%
df.shape
# Out:
# (406829, 8)

# %%
df= df[df.Country == 'France']

# %%
df.head()
# Out:
#    InvoiceNo StockCode                      Description  Quantity  \
# 26    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                  STARS GIFT TAPE        24
#
#            InvoiceDate  UnitPrice  CustomerID Country
# 26 2010-12-01 08:45:00       3.75     12583.0  France
# 27 2010-12-01 08:45:00       3.75     12583.0  France
# 28 2010-12-01 08:45:00       3.75     12583.0  France
# 29 2010-12-01 08:45:00       0.85     12583.0  France
# 30 2010-12-01 08:45:00       0.65     12583.0  France

# %%
# Removing spaces from begginings of descriptions
df['Description'] = df['Description'].str.strip()
# Some Transanction quantities are -ve. They Will be Removed.
df=df[df.Quantity >0]

# %%
#Converting the data into suitable format for association rule discovery
transactions=pd.pivot_table(data=df,index='InvoiceNo',columns='StockCode',values='Quantity', aggfunc='sum',fill_value=0)

# %%
transactions.head()
# Out:
# StockCode  10002  10120  10125  10135  11001  15036  15039  16012  16048  \
# InvoiceNo
# 536370        48      0      0      0      0      0      0      0      0
# 536852         0      0      0      0      0      0      0      0      0
# 536974         0      0      0      0      0      0      0      0      0
# 537065         0      0      0      0      0      0      0      0      0
# 537463         0      0      0      0      0      0      0      0      0
#
# StockCode  16218  ...  85232D  90030B  90030C  90184B  90184C  90201B  90201C  \
# InvoiceNo         ...
# 536370         0  ...       0       0       0       0       0       0       0
# 536852         0  ...       0       0       0       0       0       0       0
# 536974         0  ...       0       0       0       0       0       0       0
# 537065         0  ...       0       0       0       0       0       0       0
# 537463         0  ...       0       0       0       0       0       0       0
#
# StockCode  C2  M  POST
# InvoiceNo
# 536370      0  0     3
# 536852      0  0     1
# 536974      0  0     2
# 537065      0  0     9
# 537463      0  0     4
#
# [5 rows x 1522 columns]

# %% [markdown]
# **Function to Read the Product Name**

# %%
def check_id(df, stockcode):
    product_name = df[df["StockCode"] == stockcode]["Description"].unique()[0]
    return stockcode, product_name

# %%
check_id(df,10120)
# Out:
# (10120, 'DOGGY RUBBER')

# %% [markdown]
# **Function to Read StockCode from Description**

# %%
def check_Description(df,product_description):
    Scode = df[df["Description"] == product_description]["StockCode"].unique()[0]
    return product_description, Scode

# %%
check_Description(df,'POSTAGE')
# Out:
# ('POSTAGE', 'POST')

# %%
# Function to convert sums of Quantity to Binary (0,1)
def binary_converter(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
transactions_set = transactions.applymap(binary_converter)

# %%
# Removing POSTAGE Item as it is not Relevant
transactions_set.drop(columns=['POST'],inplace=True)

# %% [markdown]
# **Apriori Function With Minimum Support = 0.7**

# %%
frequent_itemsets = apriori(transactions_set, min_support=0.07, use_colnames=True)
# Out:
# /Users/amardeepsingh/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets
# Out:
#      support               itemsets
# 0   0.077121                (20712)
# 1   0.074550                (20719)
# 2   0.097686                (20724)
# 3   0.154242                (20725)
# 4   0.118252                (20726)
# 5   0.138817                (20750)
# 6   0.133676                (21080)
# 7   0.138817                (21086)
# 8   0.128535                (21094)
# 9   0.077121                (21121)
# 10  0.102828                (21212)
# 11  0.123393                (21559)
# 12  0.179949                (21731)
# 13  0.071979                (21936)
# 14  0.095116                (22027)
# 15  0.071979                (22029)
# 16  0.082262                (22090)
# 17  0.077121                (22138)
# 18  0.087404                (22139)
# 19  0.159383                (22326)
# 20  0.107969                (22328)
# 21  0.143959                (22352)
# 22  0.120823                (22382)
# 23  0.125964                (22423)
# 24  0.105398                (22492)
# 25  0.136247                (22551)
# 26  0.172237                (22554)
# 27  0.082262                (22555)
# 28  0.169666                (22556)
# 29  0.071979                (22620)
# 30  0.125964                (22629)
# 31  0.100257                (22630)
# 32  0.084833                (22662)
# 33  0.097686                (22726)
# 34  0.095116                (22727)
# 35  0.102828                (22728)
# 36  0.187661                (23084)
# 37  0.074550                (23203)
# 38  0.125964                (23206)
# 39  0.084833                (23209)
# 40  0.071979                (23254)
# 41  0.097686               (85099B)
# 42  0.102828         (21080, 21086)
# 43  0.102828         (21080, 21094)
# 44  0.123393         (21086, 21094)
# 45  0.105398         (22554, 22551)
# 46  0.089974         (22556, 22551)
# 47  0.102828         (22554, 22556)
# 48  0.071979         (22629, 22630)
# 49  0.079692         (22726, 22727)
# 50  0.074550         (22728, 22726)
# 51  0.074550         (22728, 22727)
# 52  0.100257  (21080, 21086, 21094)

# %% [markdown]
# **Association Rules from Frequent Itemsets**

# %%
# Based on Lift, Minimum Lift = 1
rules_mlxtend =association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules_mlxtend.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (21080)     (21086)            0.133676            0.138817  0.102828
# 1     (21086)     (21080)            0.138817            0.133676  0.102828
# 2     (21080)     (21094)            0.133676            0.128535  0.102828
# 3     (21094)     (21080)            0.128535            0.133676  0.102828
# 4     (21086)     (21094)            0.138817            0.128535  0.123393
#
#    confidence      lift  leverage  conviction
# 0    0.769231  5.541311  0.084271    3.731791
# 1    0.740741  5.541311  0.084271    3.341535
# 2    0.769231  5.984615  0.085646    3.776350
# 3    0.800000  5.984615  0.085646    4.331620
# 4    0.888889  6.915556  0.105550    7.843188

# %% [markdown]
#  **Sorting Rules on the Basis of Lift and Confidence**

# %%
# According to Business Case, we can sort by Lift, Confidence
rules_mlxtend[ (rules_mlxtend['lift'] >= 4) & (rules_mlxtend['confidence'] >= 0.8) ].tail()
rules_mlxtend.rename(columns={'antecedents':'LHS','consequents':'RHS'})
# Out:
#                LHS             RHS  antecedent support  consequent support  \
# 0          (21080)         (21086)            0.133676            0.138817
# 1          (21086)         (21080)            0.138817            0.133676
# 2          (21080)         (21094)            0.133676            0.128535
# 3          (21094)         (21080)            0.128535            0.133676
# 4          (21086)         (21094)            0.138817            0.128535
# 5          (21094)         (21086)            0.128535            0.138817
# 6          (22554)         (22551)            0.172237            0.136247
# 7          (22551)         (22554)            0.136247            0.172237
# 8          (22556)         (22551)            0.169666            0.136247
# 9          (22551)         (22556)            0.136247            0.169666
# 10         (22554)         (22556)            0.172237            0.169666
# 11         (22556)         (22554)            0.169666            0.172237
# 12         (22629)         (22630)            0.125964            0.100257
# 13         (22630)         (22629)            0.100257            0.125964
# 14         (22726)         (22727)            0.097686            0.095116
# 15         (22727)         (22726)            0.095116            0.097686
# 16         (22728)         (22726)            0.102828            0.097686
# 17         (22726)         (22728)            0.097686            0.102828
# 18         (22728)         (22727)            0.102828            0.095116
# 19         (22727)         (22728)            0.095116            0.102828
# 20  (21080, 21086)         (21094)            0.102828            0.128535
# 21  (21080, 21094)         (21086)            0.102828            0.138817
# 22  (21094, 21086)         (21080)            0.123393            0.133676
# 23         (21080)  (21094, 21086)            0.133676            0.123393
# 24         (21086)  (21080, 21094)            0.138817            0.102828
# 25         (21094)  (21080, 21086)            0.128535            0.102828
#
#      support  confidence      lift  leverage  conviction
# 0   0.102828    0.769231  5.541311  0.084271    3.731791
# 1   0.102828    0.740741  5.541311  0.084271    3.341535
# 2   0.102828    0.769231  5.984615  0.085646    3.776350
# 3   0.102828    0.800000  5.984615  0.085646    4.331620
# 4   0.123393    0.888889  6.915556  0.105550    7.843188
# 5   0.123393    0.960000  6.915556  0.105550   21.529563
# 6   0.105398    0.611940  4.491411  0.081932    2.225826
# 7   0.105398    0.773585  4.491411  0.081932    3.655955
# 8   0.089974    0.530303  3.892224  0.066858    1.838958
# 9   0.089974    0.660377  3.892224  0.066858    2.444873
# 10  0.102828    0.597015  3.518770  0.073605    2.060459
# 11  0.102828    0.606061  3.518770  0.073605    2.101246
# 12  0.071979    0.571429  5.699634  0.059351    2.099400
# 13  0.071979    0.717949  5.699634  0.059351    3.098855
# 14  0.079692    0.815789  8.576814  0.070400    4.912229
# 15  0.079692    0.837838  8.576814  0.070400    5.564267
# 16  0.074550    0.725000  7.421711  0.064505    3.281140
# 17  0.074550    0.763158  7.421711  0.064505    3.788061
# 18  0.074550    0.725000  7.622297  0.064770    3.290488
# 19  0.074550    0.783784  7.622297  0.064770    4.149422
# 20  0.100257    0.975000  7.585500  0.087040   34.858612
# 21  0.100257    0.975000  7.023611  0.085983   34.447301
# 22  0.100257    0.812500  6.078125  0.083762    4.620394
# 23  0.100257    0.750000  6.078125  0.083762    3.506427
# 24  0.100257    0.722222  7.023611  0.085983    3.229820
# 25  0.100257    0.780000  7.585500  0.087040    4.078056

# %% [markdown]
# **Recommending Products**

# %%
# Sorting by Lift 
sorted_rules = rules_mlxtend.sort_values("lift", ascending=False)

# %%
recom_seed=21094

# Recommendation Engine
recommendation_list = []
for idx, product in enumerate(sorted_rules["antecedents"]):
    for j in list(product):
        if j == recom_seed:
            recommendation_list.append(list(sorted_rules.iloc[idx]["consequents"])[0])
            recommendation_list = list( dict.fromkeys(recommendation_list) )
list_top5 = recommendation_list[0:5]
list_top5
# Out:
# [21080, 21086]

# %%
# Descriptions of Recommendations
for elem in list_top5:
    print(check_id(df,elem))
# Out:
# (21080, 'SET/20 RED RETROSPOT PAPER NAPKINS')
# (21086, 'SET/6 RED SPOTTY PAPER CUPS')
